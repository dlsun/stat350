# %%
from symbulate import *
# %matplotlib inline

# %% [markdown]
# # Handout 15 Normal distributions

# %% [markdown]
# # Exer 15.1

# %%
Normal(mean=70, sd=10).plot()
Normal(mean=70, sd=5).plot()
Normal(mean=80, sd=5).plot()
plt.legend(["mean=70, sd=10", "mean=70, sd=5", "mean=80, sd=5"])

# %% [markdown]
# # Exer 15.2

# %%
X = RV(Normal(mean=49.8, sd=1.3))
x = X.sim(10000)
x.plot()
Normal(mean=49.8, sd=1.3).plot()
x.mean(), x.sd()
# Out:
# (49.821003834585916, 1.2945367555486773)

# %% [markdown]
# # a)

# %%
x.count_lt(47.9) / 10000
# Out:
# 0.0689

# %%
z = (47.9-49.8)/1.3
z
# Out:
# -1.4615384615384603

# %%
Normal(0, 1).cdf(z)
# Out:
# 0.071933864240807763

# %%
Normal(mean=49.8, sd=1.3).cdf(47.9)
# Out:
# 0.071933864240807763

# %% [markdown]
# # c)

# %%
x.count_gt(53) / 10000
# Out:
# 0.0076

# %%
z = (53-49.8)/1.3
z
# Out:
# 2.4615384615384635

# %%
1-Normal(0, 1).cdf(z)
# Out:
# 0.0069171281928543937

# %%
1-Normal(mean=49.8, sd=1.3).cdf(53)
# Out:
# 0.0069171281928543937

# %% [markdown]
# # d)

# %%
Normal(mean=49.8, sd=1.3).cdf(53) - Normal(mean=49.8, sd=1.3).cdf(47.9)
# Out:
# 0.92114900756633789

# %% [markdown]
# # e)

# %%
z = Normal(0, 1).quantile(0.01)
z
# Out:
# -2.3263478740408408

# %%
49.8+z*1.3
# Out:
# 46.775747763746907

# %%
Normal(mean=49.8, sd=1.3).quantile(0.01)
# Out:
# 46.775747763746907

# %% [markdown]
# # f)

# %%
z= Normal(0, 1).quantile(0.25)
z
# Out:
# -0.67448975019608171

# %%
49.8 - 0.6745*1.3
# Out:
# 48.92315

# %%
Normal(mean=49.8, sd=1.3).quantile(0.25)
# Out:
# 48.92316332474509

# %% [markdown]
# # g)

# %%
49.8 + 0.6745*1.3
# Out:
# 50.676849999999995

# %%
Normal(mean=49.8, sd=1.3).quantile(0.75)
# Out:
# 50.676836675254904

# %% [markdown]
# ## Ex 15.3

# %% [markdown]
# # a)

# %%
M, R = RV(Normal(mean=635, sd=85) * Normal(mean=595, sd=70))
X = M + R
x = X.sim(10000)
Normal(mean=635+595, sd=sqrt(86**2 + 70**2)).plot()
x.plot()
x.mean(), x.var(), x.sd()
# Out:
# (1228.1582839138389, 12249.182537531193, 110.67602512527812)

# %%
x.count_geq(1400) / 10000
# Out:
# 0.0596

# %%
1-Normal(mean=635+595, sd=sqrt(86**2 + 70**2)).cdf(1400)
# Out:
# 0.062627126186372672

# %%
(M & R).sim(1000).plot()

# %% [markdown]
# # b)

# %%
(M > R).sim(10000).tabulate()
# Out:
# {False: 3530, True: 6470}

# %%
Y = M - R
y = Y.sim(10000)
y.plot()
Normal(mean=635-595, sd=sqrt(86**2 + 70**2)).plot()
x.mean(), x.var(), x.sd()
# Out:
# (1228.1582839138389, 12249.182537531193, 110.67602512527812)

# %%
y.count_gt(0) / 10000
# Out:
# 0.6486

# %%
1-Normal(mean=635-595, sd=sqrt(86**2 + 70**2)).cdf(0)
# Out:
# 0.64084804872075707
