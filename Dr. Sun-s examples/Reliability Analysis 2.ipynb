# %%
from symbulate import *
# %matplotlib inline

# %%
X = RV(Exponential(.1) ** 4)
R = X.apply(max)

R.sim(10000).plot()

import numpy as np
x = np.arange(0, 100, step=.1)
p = 4 * (1 - np.exp(-.1 * x)) ** 3 * (.1 * np.exp(-.1 * x))
plt.plot(x, p, 'k-')

# %%
X = RV(Exponential(.1) ** 4)
S = X.apply(min)

S.sim(10000).plot()
X[0].sim(10000).plot()
